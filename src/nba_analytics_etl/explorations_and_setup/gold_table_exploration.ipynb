# %% [markdown]
# ### Example Exploratory Notebook
#
# Use this notebook to explore the data generated by the pipeline in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
# !!! Before performing any data analysis, make sure to run the pipeline to materialize the sample datasets. The tables referenced in this notebook depend on that step.

df = spark.sql("SELECT * FROM workspace.nba_analytics.nba_gold_historical_roster")

display(df)

# %%
display(spark.sql("SELECT * FROM workspace.nba_analytics.nba_gold_player_game_performance"))

# %%
display(spark.sql("SELECT * FROM workspace.nba_analytics.nba_gold_player_opponent_stats"))

# %%
display(spark.sql("SELECT * FROM workspace.nba_analytics.nba_gold_player_season_stats"))

# %%
display(spark.sql("SELECT * FROM workspace.nba_analytics.nba_gold_team_season_stats"))
